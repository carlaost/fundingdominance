# %% [markdown]
# #Prep

# %%
import tweepy
import pandas as pd
import time
import re

# %% [markdown]
# ###Getting user names

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
users = pd.read_csv('/content/drive/MyDrive/funding-dominance/data-collection/tweet_info.csv')

# %% [markdown]
# ###Cleaning user names

# %%
usernames = []
for row in range(users.shape[0]):
  if users['tweets_period'][row] == 'hyperactive':
    usernames.append(users['usernames'][row])
print(len(usernames), '||', usernames)
# Out:
# 117 || ['OliverHeartmont', 'Jesse_Anglen', 'carlaesmall', 'chetfaliszek', 'techsportsmark', 'TirmanTom', 'Aidan_StanWorld', 'devofonik. greenmachine039 . ', 'twschiller', 'jeremiahg', 'Konrad Zemek', 'ameensol', 'dcarosa', 'hash_bender', 'darrenmarble', 'Sandip Ranjhan', 'robertsofia', 'AdamWeinstein', 'coryklippsten', 'thejessezhang', 'NMercad', 'SchlicherMartha', 'jmitch', 'jasonwenk', 'Adams_Ideas', 'GadiRusc', 'saturnial', 'Blake_Lawrence', 'js_horne', 'siddharthm83', 'MrCoreyWhite', 'lukesophinos', 'CraigJamalLewis', 'matttresidder', 'anthony_j_zhang', 'brysonbort', 'Altimor', 'PaulYacoubian', 'arlogilbert', 'chrisswenor', 'emaxerrno', ' ', 'chris_herd', 'shamir_k', ' ', 'IeeePresident', ' ', 'apoorv_bh89', 'dsaezgil', 'NoeticCyber', 'leasewithkafene', 'adamhjk', 'johnfohr', 'TheTeaGuns', 'neosec_com', 'Brandon_Brown', 'sebaudet26', 'Leishman', 'YangCLiu', 'alexadelman', 'immad', 'rereichbach', 'Sentieo', 'amasad', 'calinpac', 'bohan', 'lakhanpaln', 'jaredtparker_', 'codinghorror', 'akashrnigam', 'mg', 'YairShapira', 'mansourtarek_', 'jlowin', 'BitcoinBirch', 'dadiomov', 'kligris', 'DenehyXXL', 'giantsquidgirl', 'jainarvind', 'SleeperNan', 'Ocient', 'anshublog', 'synopsi', 'cskirchner', 'dougludlow', 'yegg', 'cgarb', 'freddier', 'akashrnigam', 'Hhorsley', 'DonSchererCEO', 'amasad', 'Gmandelzis', 'EynatGuez', 'nickfajt', 'Mr312', 'JordanDFeldman', 'rauchg', 'KentaroKawamori', 'biilmann', 'BrendanEich', 'Brandon_Brown', 'MarkDouglas', 'Jobvo', 'ralf_jokr', 'joshuamotta', 'WesSchroll', 'EynatGuez', 'ralf_jokr', 'theryanking', 'paddypower', 'bohan', 'RonnieSloanMck', 'Mnylif', 'BKBuchanan', 'brianjesposito']

# %% [markdown]
# #Scraper

# %%
consumer_key = "cdV7bjdgWQSxMMVCoAVjUcFtu"
consumer_secret = "m0pUurMEa4vGqlkynbEBVFiOye9tjZSDsVlGadsPnF73iHvClA"
access_token = "1397642727517478918-SGxRcmFwS3zBDDCrPx8Vt4RfE93GOO"
access_token_secret = "FMYoaEGWpNrB6uJN8jhRu3L5GPYvGwWWk4FSvkynsyGpG"

# %%
def username_tweets_to_csv(username,count):
    try:      
        # Creation of query method using parameters
        tweets = tweepy.Cursor(api.user_timeline,screen_name=username, tweet_mode="extended", include_rts=False,).items(count)

        # Pulling information from tweets iterable object
        tweets_list = [[tweet.created_at, tweet.id, tweet.full_text] for tweet in tweets]

        # Creation of dataframe from tweets list
        # Add or remove columns as you remove tweet information
        tweets_df = pd.DataFrame(tweets_list,columns=['Datetime', 'Tweet Id', 'Text'])

        # Converting dataframe to CSV 
        tweets_df.to_csv('/content/drive/MyDrive/funding-dominance/data-collection/tweets/{}-3000-tweets.csv'.format(username), sep=',', index = False)

    except BaseException as e:
          print(username, '- failed on_status,',str(e))
          time.sleep(3)

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
for i in range(len(usernames)):
  username = usernames[i]
  username_tweets_to_csv(username, 3000)
